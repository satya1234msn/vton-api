# %% [markdown]
# # vton-api Kaggle starter
# This notebook prepares the environment and runs the API with a Cloudflare tunnel.

# %%
# %%bash
# set -e
# mkdir -p /kaggle/working/vton-api
# echo 'Uploading package into /kaggle/working/vton-api (if you uploaded zip, extract it)'

# %%
# %%bash
# # install minimal requirements
# pip install --upgrade pip
# pip install -r /kaggle/working/vton-api/requirements.txt || true
# ls -la /kaggle/working/vton-api

# %% [markdown]
# ## Upload IDM-VTON repo + model weights
# Either upload files via the Kaggle UI into `/kaggle/working/vton-api/IDM-VTON` and `/kaggle/working/vton-api/models/IDM-VTON/`,
# or use `git clone` / `wget` commands here to download them.

# %%
# %%bash
# chmod +x /kaggle/working/vton-api/run_api.sh || true
# nohup /kaggle/working/vton-api/run_api.sh > /kaggle/working/vton-api/run_api.log 2>&1 &
# sleep 5
# tail -n +1 /kaggle/working/vton-api/uvicorn.log || true
# tail -n +1 /kaggle/working/vton-api/run_api.log || true
